# %%
from PIL import Image
import pytesseract

pytesseract.pytesseract.tesseract_cmd = (
    r"C:\Program Files\Tesseract-OCR\tesseract.exe"
)

img = Image.open("Sinhala_Images/test1.jpg")

text = pytesseract.image_to_string(
    img,
    lang="sin"
)

print(text)
# Out:
# ආසියාතික භාෂාවන්ට
# බොහෝ වෙනස්්‌ විය හැකිය.
# මෙම ක ාහ්‍යනා ගැනීම ඔබට
#
# හඳුනා ගැනීමට
# කාර වේ.

# %%
img = Image.open("Sinhala_Images/test2.jpg")

text = pytesseract.image_to_string(
    img,
    lang="sin"
)

print(text)
# Out:
# 48. (1) පාර්ලිමේන්තුව විසුරුවා හරිනු ලැබීමත්‌ මහ මැතිවරණය
# අවසාන වීමත්‌ අතර කාලය තුළ හැර, ධූරයෙන්‌ ඉවත්‌ කරනු ලැබීමෙන්‌
# 'හෝ ඉල්ලා අස්වීමෙන්‌ හෝ අන්‍යාකාරයකින්‌ හෝ අග්‍රාමාත්‍යවරයා
# ධූරය දැරීම නතර වූ විට, 700 වන ව්‍යවස්ථාව යටතේ ස්වකීය බලතල
# ක්‍රියාත්මක කරමින්‌ ජනාධිපතිවරයා විසින්‌ පාර්ලිමේන්තුව විසුරුවා
# හැර ඇතොත්‌ මිස, අමාත්‍ය මණ්ඩලය වචිසිරෙන්නේය. එසේ වූ විට
# ජනාධිපතිවරයා විසින්‌ 42 වන, 43 වන, 44 වන සහ 45 වන ව්‍යවස්ථා
# අනුව අග්‍රාමාත්‍යවරයකු ද, අමාත්‍ය මණ්ඩලයේ අමාත්‍යවරයන්‌ ද,
# අමාත්‍ය මණ්ඩලයේ සාමාජිකයන්‌ නොවන අමාත්‍යවරයන්‌ ද,
# නියෝජ්‍ය අමාත්‍යවරයන්ද පත්‌ කළ යුත්තේ ය :
#
# අමාත්‍ය මණ්ඩල,
# විසිරීම.

# %%
img = Image.open("Sinhala_Images/test3.png")

text = pytesseract.image_to_string(
    img,
    lang="sin"
)

print(text)
# Out:
# සිංහල

# %%
img = Image.open("Sinhala_Images/test4.jpg")

text = pytesseract.image_to_string(
    img,
    lang="sin"
)

print(text)
# Out:
# මිනිස්සුන්ව මානසිකව චට්ටන්නෙපා
# ඒක ලොකු පචක්‌
# මොකද මනස සුචපත්‌ කරන්න ලේසි නෑ..
#
# හැම මනුස්සයෙක්ගෙම
# හිත හයිය උනානම්‌
# හැමදේම දරාගන්න..
# මානසික ලෙඩ්ඩු නෑ අද
# හිත්‌ බිදගත්ත.
#
# බෲ
